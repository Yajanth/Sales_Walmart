# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data=pd.read_csv("../input/walmart-dataset/Walmart.csv")
data
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode    Customer Name  \
# 0     CA-2013-138688  13-06-2013  17-06-2013    Second Class  Darrin Van Huff
# 1     CA-2011-115812  09-06-2011  14-06-2011  Standard Class  Brosina Hoffman
# 2     CA-2011-115812  09-06-2011  14-06-2011  Standard Class  Brosina Hoffman
# 3     CA-2011-115812  09-06-2011  14-06-2011  Standard Class  Brosina Hoffman
# 4     CA-2011-115812  09-06-2011  14-06-2011  Standard Class  Brosina Hoffman
# ...              ...         ...         ...             ...              ...
# 3198  CA-2013-125794  30-09-2013  04-10-2013  Standard Class     Maris LaWare
# 3199  CA-2014-121258  27-02-2014  04-03-2014  Standard Class      Dave Brooks
# 3200  CA-2014-121258  27-02-2014  04-03-2014  Standard Class      Dave Brooks
# 3201  CA-2014-121258  27-02-2014  04-03-2014  Standard Class      Dave Brooks
# 3202  CA-2014-119914  05-05-2014  10-05-2014    Second Class     Chris Cortes
#
# ...

# %%
data["Country"].replace({"United States": "USA"}, inplace = True)
data
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode    Customer Name  \
# 0     CA-2013-138688  13-06-2013  17-06-2013    Second Class  Darrin Van Huff
# 1     CA-2011-115812  09-06-2011  14-06-2011  Standard Class  Brosina Hoffman
# 2     CA-2011-115812  09-06-2011  14-06-2011  Standard Class  Brosina Hoffman
# 3     CA-2011-115812  09-06-2011  14-06-2011  Standard Class  Brosina Hoffman
# 4     CA-2011-115812  09-06-2011  14-06-2011  Standard Class  Brosina Hoffman
# ...              ...         ...         ...             ...              ...
# 3198  CA-2013-125794  30-09-2013  04-10-2013  Standard Class     Maris LaWare
# 3199  CA-2014-121258  27-02-2014  04-03-2014  Standard Class      Dave Brooks
# 3200  CA-2014-121258  27-02-2014  04-03-2014  Standard Class      Dave Brooks
# 3201  CA-2014-121258  27-02-2014  04-03-2014  Standard Class      Dave Brooks
# 3202  CA-2014-119914  05-05-2014  10-05-2014    Second Class     Chris Cortes
#
# ...

# %%
data.isnull()
# Out:
#       Order ID  Order Date  Ship Date  Ship Mode  Customer Name  Segment  \
# 0        False       False      False      False          False    False
# 1        False       False      False      False          False    False
# 2        False       False      False      False          False    False
# 3        False       False      False      False          False    False
# 4        False       False      False      False          False    False
# ...        ...         ...        ...        ...            ...      ...
# 3198     False       False      False      False          False    False
# 3199     False       False      False      False          False    False
# 3200     False       False      False      False          False    False
# 3201     False       False      False      False          False    False
# 3202     False       False      False      False          False    False
#
#       Country   City  State  Category  Sub-Category  Product Name  Sales  \
# ...

# %%
sns.heatmap(data.isnull(),yticklabels=False)
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x='Quantity',data=data)
# Out:
# <AxesSubplot:xlabel='Quantity', ylabel='count'>

# %%
data['Sub-Category'].hist(bins=30,color='darkred')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20,10))
sns.countplot(x='Sub-Category',data=data)
# Out:
# <AxesSubplot:xlabel='Sub-Category', ylabel='count'>

# %%
plt.figure(figsize=(20,10))
sns.boxplot(x='City',y='Sales',data=data)
# Out:
# <AxesSubplot:xlabel='City', ylabel='Sales'>

# %%
plt.figure(figsize=(20,10))
sns.countplot(x='Quantity',data=data)
# Out:
# <AxesSubplot:xlabel='Quantity', ylabel='count'>

# %%
plt.figure(figsize=(20,10))
sns.countplot(x='Segment',data=data)
# Out:
# <AxesSubplot:xlabel='Segment', ylabel='count'>
